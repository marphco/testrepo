# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Marco Franco**<br>Data Scientist

# %% [markdown]
# *I am interested in data science because I think that every company needs to study, analyze and organize their business to improve performance and profits.
# As a Designer I've always cared about the aesthetics and functionality of all the work I've done. It intrigues me to think that there is a possibility of connecting my passion for design with a possible use of data science to improve the impact and efficiency of a graphic work.*

# %% [markdown]
# ### The following code is going to print a simple addition between a variable and an integer number. ###

# %%
ten = 10
print(ten + 15)
# Out:
# 25

# %% [markdown]
# **Bulleted list**
#
# * List item 1
# * List item 2
# * List item 3
#
# **Horizontal Rules**
#
# ------
#
# **Numbered List**
#
# 1. List item 1
# 2. List item 2
# 3. List item 3
#
# **Blockquote**
# >This is a blockquote
